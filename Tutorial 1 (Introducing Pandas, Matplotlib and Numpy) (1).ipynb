# %% [markdown]
# Python for Data Science
#
# In this tutorial we will be covering the following 5 things:
# 1. Importing Python libraries
# 2. Reading csv files from pandas
# 3. Use of apply function
# 4. Data Visualization using Matplotlib
# 5. Use of numpy functions

# %%
import pandas as pd #for data manipulation and analysis
import numpy as np #for numerical computation
import matplotlib.pyplot as plt #for data visualization

# %% [markdown]
# Import Data using Pandas Data Frame:
#
# A DataFrame is a data structure that organizes data into a 2-dimensional table of rows and columns, much like a spreadsheet. DataFrames are one of the most common data structures used in modern data analytics because they are a flexible and intuitive way of storing and working with data.

# %%
df = pd.read_csv(r"C:\Users\Toshiba\OneDrive\Desktop\2019.csv")

# %%
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df.head() #selects the first 5 rows of the data
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
df.describe() #it gives 8 point summary of our numeric data
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %%
print(df.shape) #Tells no. of rows and columns in data
print(df.columns) #to display all the columns in our data
# Out:
# (156, 9)
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df.isnull().sum() #tells the boolean value that whether the data is missing and sum tells the count of it
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
df["GDP per capita"] #to select an attribute from the data
# Out:
# 0      1.340
# 1      1.383
# 2      1.488
# 3      1.380
# 4      1.396
#        ...
# 151    0.359
# 152    0.476
# 153    0.350
# 154    0.026
# 155    0.306
# Name: GDP per capita, Length: 156, dtype: float64

# %% [markdown]
# Use of .apply function
#
# .apply() function is a pandas way to perform iterations on rows/columns. It takes advantage of vectorizes techniques and speeds up execution of simple and complex operations by many times.

# %%
#The following example passes a function and checks the value of each element in series and returns low, normal 
or High accordingly.
def life_range(num): 
  
    if num < 0: 
        return "Low"
  
    elif num >= 0 and num < 1: 
        return "Normal"
  
    else: 
        return "High"

# %%
#take an attribute 
Healthy_life = df["Healthy life expectancy"]

# %%
Healthy_life
# Out:
# 0      0.986
# 1      0.996
# 2      1.028
# 3      1.026
# 4      0.999
#        ...
# 151    0.614
# 152    0.499
# 153    0.361
# 154    0.105
# 155    0.295
# Name: Healthy life expectancy, Length: 156, dtype: float64

# %%
# passing function to apply and storing returned series in range 
range = Healthy_life.apply(life_range)

# %%
range
# Out:
# 0      Normal
# 1      Normal
# 2        High
# 3        High
# 4      Normal
#         ...
# 151    Normal
# 152    Normal
# 153    Normal
# 154    Normal
# 155    Normal
# Name: Healthy life expectancy, Length: 156, dtype: object

# %%
df['Healthy Life Category'] = range #create new column in the dataset

# %%
df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# 5               6               Switzerland  7.480           1.452
# 6               7                    Sweden  7.343           1.387
# 7               8               New Zealand  7.307           1.303
# 8               9                    Canada  7.278           1.365
# 9              10                   Austria  7.246           1.376
# 10             11                 Australia  7.228           1.372
# 11             12                Costa Rica  7.167           1.034
# 12             13                    Israel  7.139           1.276
# ...

# %%
df['Healthy Life Category'].value_counts() #Checks the ditribution of categorical columns
# Out:
# Normal    137
# High       19
# Name: Healthy Life Category, dtype: int64

# %% [markdown]
# Data Visualization with Matplotlib:
#
# Making informative visualizations (sometimes called plots) is one of the most important tasks in data analysis. It may be a part of the exploratory process—for example,to help identify outliers or needed data transformations, or as a way of generating ideas for models. For others, building an interactive visualization for the web may be the end goal. Python has many add-on libraries for making static or dynamic visualizations, but I’ll be mainly focused on matplotlib and libraries that build on top of it.

# %%
#simple histogram
n, bins, patches = plt.hist(x = df["Healthy life expectancy"],bins =6)
plt.setp(patches[0], 'facecolor', 'g')
plt.setp(patches[1], 'facecolor', 'r')

plt.xlabel('Life Expectancy')
plt.ylabel('Frequency')
plt.title("Histogram of Healthy Life Expectancy")
# Out:
# Text(0.5, 1.0, 'Histogram of Healthy Life Expectancy')

# %%
bins #distribution of patches
# Out:
# array([0.        , 0.19016667, 0.38033333, 0.5705    , 0.76066667,
#        0.95083333, 1.141     ])

# %%
n #height of the patches
# Out:
# array([ 3., 14., 25., 29., 54., 31.])

# %% [markdown]
# Numpy functions:
#
# NumPy, short for Numerical Python, is one of the most important foundational packages for numerical computing and manipulation of data stored in arrays.

# %%
a = np.array([9,10,17,3]) # One-dimensional array

b = np.array([[3, 5, 2, 4], 
              [7, 6, 8, 8],
              [1, 6, 7, 7]])  # Two-dimensional array

c = np.array([[8, 1, 5, 9], 
              [8, 9, 4, 3],
              [0, 3, 5, 0]])  # Two-dimensional array

# %% [markdown]
# Each array has attributes ndim (the number of dimensions), shape (the size of each dimension), and size (the total size of the array):

# %%
print("Dimenssion of array a is : ", a.ndim)
print("Shape of array a is :", a.shape)
print("Size of array a is = ", a.size)
# Out:
# Dimenssion of array a is :  1
# Shape of array a is : (4,)
# Size of array a is =  4

# %%
print("Dimenssion of array b is : ", b.ndim)
print("Shape of array b is :", b.shape)
print("Size of array b is 3 * 4 = ", b.size)
# Out:
# Dimenssion of array b is :  2
# Shape of array b is : (3, 4)
# Size of array b is 3 * 4 =  12

# %%
#multiplying a constant with array
scalar =  c*3
print(scalar)
# Out:
# [[24  3 15 27]
#  [24 27 12  9]
#  [ 0  9 15  0]]

# %%
#adding b and c because they have same dimensions
add = b + c
print(add)
# Out:
# [[11  6  7 13]
#  [15 15 12 11]
#  [ 1  9 12  7]]

# %%
# element wise multipication
multiply = b*c 
print(multiply)
# Out:
# [[24  5 10 36]
#  [56 54 32 24]
#  [ 0 18 35  0]]

# %%
#taking square of every element in c
square = b**2
print(square)
# Out:
# [[ 9 25  4 16]
#  [49 36 64 64]
#  [ 1 36 49 49]]

# %%
#are elements of b > than c
logical= b > c
print(logical)
# Out:
# [[False  True False False]
#  [False False  True  True]
#  [ True  True  True  True]]

# %%
b
# Out:
# array([[3, 5, 2, 4],
#        [7, 6, 8, 8],
#        [1, 6, 7, 7]])

# %%
np.min(b)           # Minimum of the flattened array
# Out:
# 1

# %%
np.min(b, axis=0)   # Minima along the first axis which means the minimum in first column,second column and so on.
# Out:
# array([1, 5, 2, 4])

# %%
np.min(b,axis = 1) # Minima along the second axis which means the minimum of first row,second row and so on.
# Out:
# array([2, 6, 1])

# %%
np.max(b)         # Maximum of the flattened array
# Out:
# 8

# %% [markdown]
# numpy.argmin : Returns the indices of the minimum values along an axis
#
# numpy.argmax : Returns the indices of the maximum values along an axis
#
# Remember : Indexing in Python starts at 0

# %%
np.argmin(b,axis = 1,) #this means return the minimum index of array by looking at each row.
# Out:
# array([2, 1, 0], dtype=int64)

# %%
np.argmin(b,axis = 0,) #this means return the minimum index of array by looking at each column
# Out:
# array([2, 0, 0, 0], dtype=int64)

# %%
np.argmax(b,axis = 1,) #this means return the maximum index of array by looking at each row.
# Out:
# array([1, 2, 2], dtype=int64)

# %%
np.argmax(b,axis = 0,) #this means return the maximum index of array by looking at each column
# Out:
# array([1, 1, 1, 1], dtype=int64)

# %% [markdown]
# END
